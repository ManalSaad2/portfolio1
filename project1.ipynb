# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly.express as px

# %%
df= pd.read_excel("Copy of adidas 6.xlsx" )

# %%
df.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200      60000.0
# 1    Men's Athletic Footwear            50.0        1000      50000.0
# 2    Women's Street Footwear            40.0        1000      40000.0
# 3  Women's Athletic Footwear            45.0         850      38250.0
# 4              Men's Apparel            60.0         900      54000.0
#
#    Operating Profit Sales Method
# 0           30000.0     In-store
# 1           15000.0     In-store
# ...

# %%
df.sample(5)
# Out:
#            Retailer  Retailer ID Invoice Date     Region          State  \
# 1628    Foot Locker      1128299   2021-09-25  Southeast       Virginia
# 3534  Sports Direct      1185732   2021-03-03  Northeast    Connecticut
# 1166         Amazon      1185732   2021-10-30  Northeast          Maine
# 7751    Foot Locker      1185732   2021-10-19  Northeast  New Hampshire
# 8303  Sports Direct      1197831   2021-04-06      South      Tennessee
#
#             City                    Product  Price per Unit  Units Sold  \
# 1628    Richmond            Women's Apparel            45.0         250
# 3534    Hartford  Women's Athletic Footwear            35.0         100
# 1166    Portland      Men's Street Footwear            40.0         450
# 7751  Manchester    Women's Street Footwear            59.0          54
# 8303   Knoxville  Women's Athletic Footwear            20.0         179
#
#       Total Sales  Operating Profit Sales Method
# 1628      11250.0          3375.000     In-store
# ...

# %%
df.isnull().sum()
# Out:
# Retailer            0
# Retailer ID         0
# Invoice Date        0
# Region              7
# State               0
# City                0
# Product             0
# Price per Unit      2
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Sales Method        0
# dtype: int64

# %%
df.isnull().sum().plot(kind="bar")
# Out:
# <Axes: >

# %%
df.describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_e77af_row0_col0, #T_e77af_row2_col2, #T_e77af_row2_col3, #T_e77af_row2_col4, #T_e77af_row2_col5, #T_e77af_row3_col2, #T_e77af_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e77af_row0_col2, #T_e77af_row0_col3, #T_e77af_row6_col0, #T_e77af_row6_col4, #T_e77af_row6_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e77af_row0_col4 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_e77af_row0_col5 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_e77af_row1_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_e77af_row1_col2, #T_e77af_row3_col5, #T_e77af_row4_col2, #T_e77af_row5_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_e77af_row1_col3 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_e77af_row1_col4 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_e77af_row1_col5 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# ...

# %%
df['Price per Unit'].mean()
# Out:
# 45.21280960750285

# %%
df["Price per Unit"].fillna(df["Price per Unit"].mean())
# Out:
# 0       50.0
# 1       50.0
# 2       40.0
# 3       45.0
# 4       60.0
#         ...
# 9643    50.0
# 9644    41.0
# 9645    41.0
# 9646    42.0
# 9647    29.0
# Name: Price per Unit, Length: 9641, dtype: float64

# %%
df.isnull().sum()
# Out:
# Retailer            0
# Retailer ID         0
# Invoice Date        0
# Region              0
# State               0
# City                0
# Product             0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Sales Method        0
# Day                 0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['Total Sales']=df['Price per Unit']*df['Units Sold']

# %%
df.groupby("Region")["Total Sales"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby("Region")["Total Sales"].sum()
# Out:
# Region
# Midwest      1.665443e+07
# Northeast    2.507457e+07
# South        2.054525e+07
# Southeast    2.137444e+07
# West         3.634441e+07
# Name: Total Sales, dtype: float64

# %%
R=pd.DataFrame(R)

# %%
R["per"]=R["Total Sales"]/R["Total Sales"].sum()*100

# %%
R
# Out:
#             Total Sales        per
# Region
# Midwest    1.665443e+07  13.879493
# Northeast  2.507457e+07  20.896679
# South      2.054525e+07  17.122028
# Southeast  2.137444e+07  17.813054
# West       3.634441e+07  30.288747

# %%
df["Invoice Date"] = pd.to_datetime(df["Invoice Date"])
df["Day"] = df["Invoice Date"].dt.day_name()

# %%
df
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %%
df.groupby("Day")["Total Sales"].mean()
# Out:
# Day
# Friday       13744.389201
# Monday       11962.529743
# Saturday     11259.231152
# Sunday       11499.667147
# Thursday     14443.313477
# Tuesday      12341.266443
# Wednesday    11855.909988
# Name: Total Sales, dtype: float64

# %%
plt.figure(figsize=(15,7))
px.scatter(df,x="Invoice Date",y="Total Sales",color="Sales Method")

# %%
px.pie(df,names="Sales Method",values="Total Sales")

# %%
df.groupby("State")["Total Sales"].sum().sort_values()
# Out:
# State
# Nebraska          7.288380e+05
# Minnesota         9.039180e+05
# Iowa              9.098110e+05
# Wisconsin         9.488940e+05
# North Dakota      9.509300e+05
# Maryland          9.511340e+05
# South Dakota      1.041101e+06
# Indiana           1.084723e+06
# Maine             1.129728e+06
# Illinois          1.184063e+06
# Missouri          1.189515e+06
# Rhode Island      1.202256e+06
# New Jersey        1.220446e+06
# Kansas            1.225314e+06
# Kentucky          1.241148e+06
# West Virginia     1.311160e+06
# Utah              1.387620e+06
# Pennsylvania      1.478794e+06
# Delaware          1.508537e+06
# Oklahoma          1.512059e+06
# Massachusetts     1.578435e+06
# Connecticut       1.646448e+06
# Arkansas          1.802672e+06
# Alaska            1.810428e+06
# Montana           1.930761e+06
# Vermont           2.041598e+06
# Mississippi       2.218609e+06
# Arizona           2.254096e+06
# Ohio              2.269283e+06
# Wyoming           2.282342e+06
# ...

# %%
# !pip install pivottablejs

# %%
from pivottablejs import pivot_ui
pivot_ui(df)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
